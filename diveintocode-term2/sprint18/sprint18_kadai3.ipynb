# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-998eb668-ac45-4491-9d58-ac6de31c5cc9" name="files[]" multiple disabled />
#      <output id="result-998eb668-ac45-4491-9d58-ac6de31c5cc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving simpsons_dataset.zip to simpsons_dataset.zip

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.chdir('Colab Notebooks')

# %%
os.chdir('DIC')

# %%
os.chdir('ObjectDetection-master')

# %%
# %run train.py -p annotation.txt
# Out:
# Parsing annotation files
# Training images per class (19 classes) :
# {'abraham_grampa_simpson': 687,
#  'apu_nahasapeemapetilon': 206,
#  'bart_simpson': 650,
#  'bg': 0,
#  'charles_montgomery_burns': 650,
#  'chief_wiggum': 209,
#  'comic_book_guy': 208,
#  'edna_krabappel': 212,
#  'homer_simpson': 718,
#  'kent_brockman': 213,
#  'krusty_the_clown': 429,
#  'lisa_simpson': 756,
#  'marge_simpson': 629,
#  'milhouse_van_houten': 210,
#  'moe_szyslak': 403,
#  'ned_flanders': 675,
#  'nelson_muntz': 219,
#  'principal_skinner': 614,
#  'sideshow_bob': 201}
# -------------------------------
# path to config file : ./save/train_20190611-053514_config.pickle
# -------------------------------
# Epoch 1/100
#   2/150 [..............................] - ETA: 26:38 - rpn_cls: 5.3867 - rpn_regr: 0.1118 - detector_cls: 2.2083 - detector_regr: 0.0000e+00Exception: 'a' cannot be empty unless no samples are taken
#   4/150 [..............................] - ETA: 13:33 - rpn_cls: 6.4121 - rpn_regr: 0.2211 - detector_cls: 2.9607 - detector_regr: 0.1063Exception: 'NoneType' object is not subscriptable
# 149/150 [============================>.] - ETA: 0s - rpn_cls: 4.4602 - rpn_regr: 0.1889 - detector_cls: 3.6447 - detector_regr: 1.6343Average number of overlapping bounding boxes from RPN = 14.573333333333334 for 150 previous iterations
# 150/150 [==============================] - 59s 393ms/step - rpn_cls: 4.4538 - rpn_regr: 0.1887 - detector_cls: 3.6385 - detector_regr: 1.6299
# Exception: 'NoneType' object is not subscriptable
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 14.611842105263158
# Classifier accuracy for bounding boxes from RPN: 0.5333333333333333
# Loss RPN classifier: 3.5011400928631518
# Loss RPN regression: 0.1458868684868018
# Loss Detector classifier: 2.715046996908883
# Loss Detector regression: 0.9810087088743845
# Elapsed time: 59.29582667350769[s]
# Total loss decreased from inf to 7.3430826671332206, saving weights
# Epoch 2/100
#  25/150 [====>.........................] - ETA: 32s - rpn_cls: 1.0936 - rpn_regr: 0.1136 - detector_cls: 2.0764 - detector_regr: 0.4971Exception: 'NoneType' object is not subscriptable
#  71/150 [=============>................] - ETA: 20s - rpn_cls: 1.3856 - rpn_regr: 0.1164 - detector_cls: 2.0920 - detector_regr: 0.5047Exception: 'NoneType' object is not subscriptable
# 148/150 [============================>.] - ETA: 0s - rpn_cls: 1.7583 - rpn_regr: 0.1136 - detector_cls: 2.1159 - detector_regr: 0.5047Average number of overlapping bounding boxes from RPN = 19.3 for 150 previous iterations
# 150/150 [==============================] - 38s 255ms/step - rpn_cls: 1.7639 - rpn_regr: 0.1135 - detector_cls: 2.1163 - detector_regr: 0.5045
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.3841059602649
# Classifier accuracy for bounding boxes from RPN: 0.535
# Loss RPN classifier: 2.1730702552272447
# Loss RPN regression: 0.11022583470369379
# Loss Detector classifier: 2.1461602262655894
# Loss Detector regression: 0.48656017045180006
# Elapsed time: 79.4374418258667[s]
# Total loss decreased from 7.3430826671332206 to 4.916016486648329, saving weights
# Epoch 3/100
# 106/150 [====================>.........] - ETA: 11s - rpn_cls: 1.9963 - rpn_regr: 0.1248 - detector_cls: 2.0114 - detector_regr: 0.4164Exception: 'NoneType' object is not subscriptable
# 147/150 [============================>.] - ETA: 0s - rpn_cls: 2.0087 - rpn_regr: 0.1239 - detector_cls: 2.0181 - detector_regr: 0.4193Average number of overlapping bounding boxes from RPN = 20.386666666666667 for 150 previous iterations
# 150/150 [==============================] - 38s 250ms/step - rpn_cls: 2.0085 - rpn_regr: 0.1239 - detector_cls: 2.0186 - detector_regr: 0.4195
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.28476821192053
# Classifier accuracy for bounding boxes from RPN: 0.55
# Loss RPN classifier: 2.0285706054517374
# Loss RPN regression: 0.12615678124129773
# Loss Detector classifier: 2.0446926982700826
# Loss Detector regression: 0.4272058575352033
# Elapsed time: 41.67715334892273[s]
# Total loss decreased from 4.916016486648329 to 4.626625942498321, saving weights
# Epoch 4/100
# 146/150 [============================>.] - ETA: 0s - rpn_cls: 1.9329 - rpn_regr: 0.1459 - detector_cls: 1.9574 - detector_regr: 0.4520Average number of overlapping bounding boxes from RPN = 20.086666666666666 for 150 previous iterations
# 150/150 [==============================] - 36s 241ms/step - rpn_cls: 1.9341 - rpn_regr: 0.1456 - detector_cls: 1.9578 - detector_regr: 0.4524
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.026490066225165
# Classifier accuracy for bounding boxes from RPN: 0.5416666666666666
# Loss RPN classifier: 2.008445408347188
# Loss RPN regression: 0.13372381313548734
# Loss Detector classifier: 1.975300370256106
# Loss Detector regression: 0.4649828990797202
# Elapsed time: 38.8572199344635[s]
# Total loss decreased from 4.626625942498321 to 4.582452490818501, saving weights
# Epoch 5/100
# 131/150 [=========================>....] - ETA: 4s - rpn_cls: 2.3148 - rpn_regr: 0.1144 - detector_cls: 2.1147 - detector_regr: 0.4513Exception: 'NoneType' object is not subscriptable
# 145/150 [============================>.] - ETA: 1s - rpn_cls: 2.3137 - rpn_regr: 0.1144 - detector_cls: 2.1153 - detector_regr: 0.4507Average number of overlapping bounding boxes from RPN = 22.1 for 150 previous iterations
# 150/150 [==============================] - 36s 238ms/step - rpn_cls: 2.3114 - rpn_regr: 0.1144 - detector_cls: 2.1148 - detector_regr: 0.4502
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.125827814569536
# Classifier accuracy for bounding boxes from RPN: 0.53
# Loss RPN classifier: 2.2501014049927517
# Loss RPN regression: 0.11371862417707841
# Loss Detector classifier: 2.0950818280378978
# Loss Detector regression: 0.43440362458427745
# Elapsed time: 38.472970962524414[s]
# Epoch 6/100
#  44/150 [=======>......................] - ETA: 24s - rpn_cls: 2.4294 - rpn_regr: 0.1296 - detector_cls: 2.0418 - detector_regr: 0.4784Exception: 'NoneType' object is not subscriptable
#  79/150 [==============>...............] - ETA: 16s - rpn_cls: 2.3285 - rpn_regr: 0.1311 - detector_cls: 2.0447 - detector_regr: 0.4801Exception: 'NoneType' object is not subscriptable
# 144/150 [===========================>..] - ETA: 1s - rpn_cls: 2.0433 - rpn_regr: 0.1268 - detector_cls: 2.0342 - detector_regr: 0.4764Average number of overlapping bounding boxes from RPN = 20.1 for 150 previous iterations
# 150/150 [==============================] - 36s 242ms/step - rpn_cls: 2.0291 - rpn_regr: 0.1265 - detector_cls: 2.0331 - detector_regr: 0.4758
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.960264900662253
# Classifier accuracy for bounding boxes from RPN: 0.5366666666666666
# Loss RPN classifier: 1.6899823898262805
# Loss RPN regression: 0.1203804956190288
# Loss Detector classifier: 2.0083085788289705
# Loss Detector regression: 0.46588834663232165
# Elapsed time: 36.449002265930176[s]
# Total loss decreased from 4.582452490818501 to 4.284559810906601, saving weights
# Epoch 7/100
#  37/150 [======>.......................] - ETA: 28s - rpn_cls: 1.5322 - rpn_regr: 0.0954 - detector_cls: 2.0339 - detector_regr: 0.3805Exception: 'NoneType' object is not subscriptable
# 143/150 [===========================>..] - ETA: 1s - rpn_cls: 1.8943 - rpn_regr: 0.0999 - detector_cls: 2.0405 - detector_regr: 0.4320Average number of overlapping bounding boxes from RPN = 21.386666666666667 for 150 previous iterations
# 150/150 [==============================] - 38s 256ms/step - rpn_cls: 1.9000 - rpn_regr: 0.0999 - detector_cls: 2.0382 - detector_regr: 0.4331
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.503311258278146
# Classifier accuracy for bounding boxes from RPN: 0.5333333333333333
# Loss RPN classifier: 2.0391682324501934
# Loss RPN regression: 0.09959288386317591
# Loss Detector classifier: 1.9956022940079372
# Loss Detector regression: 0.45497202351689336
# Elapsed time: 41.22388672828674[s]
# Epoch 8/100
# 142/150 [===========================>..] - ETA: 1s - rpn_cls: 2.6562 - rpn_regr: 0.0939 - detector_cls: 1.9835 - detector_regr: 0.3987Average number of overlapping bounding boxes from RPN = 21.173333333333332 for 150 previous iterations
# 150/150 [==============================] - 37s 249ms/step - rpn_cls: 2.6414 - rpn_regr: 0.0942 - detector_cls: 1.9810 - detector_regr: 0.3993
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.52317880794702
# Classifier accuracy for bounding boxes from RPN: 0.5483333333333333
# Loss RPN classifier: 2.338251678768728
# Loss RPN regression: 0.10127873873338103
# Loss Detector classifier: 1.9429870609442392
# Loss Detector regression: 0.41017012188831964
# Elapsed time: 37.65537452697754[s]
# Epoch 9/100
# 141/150 [===========================>..] - ETA: 2s - rpn_cls: 1.6567 - rpn_regr: 0.1081 - detector_cls: 2.0091 - detector_regr: 0.4572Average number of overlapping bounding boxes from RPN = 21.7 for 150 previous iterations
# 150/150 [==============================] - 37s 247ms/step - rpn_cls: 1.6569 - rpn_regr: 0.1082 - detector_cls: 2.0057 - detector_regr: 0.4567
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.52980132450331
# Classifier accuracy for bounding boxes from RPN: 0.5333333333333333
# Loss RPN classifier: 1.6162176594058772
# Loss RPN regression: 0.11038172418872515
# Loss Detector classifier: 1.9508801841735839
# Loss Detector regression: 0.4494764260450999
# Elapsed time: 37.28259754180908[s]
# Total loss decreased from 4.284559810906601 to 4.1269559938132865, saving weights
# Epoch 10/100
# 140/150 [===========================>..] - ETA: 2s - rpn_cls: 1.6340 - rpn_regr: 0.1260 - detector_cls: 1.9245 - detector_regr: 0.4540Average number of overlapping bounding boxes from RPN = 22.073333333333334 for 150 previous iterations
# 150/150 [==============================] - 40s 267ms/step - rpn_cls: 1.6272 - rpn_regr: 0.1252 - detector_cls: 1.9257 - detector_regr: 0.4545
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.05960264900662
# Classifier accuracy for bounding boxes from RPN: 0.5216666666666666
# Loss RPN classifier: 1.506243518347513
# Loss RPN regression: 0.11483357159420848
# Loss Detector classifier: 1.942494829595089
# Loss Detector regression: 0.45840854133168857
# Elapsed time: 42.853331089019775[s]
# Total loss decreased from 4.1269559938132865 to 4.021980460868499, saving weights
# Epoch 11/100
# 139/150 [==========================>...] - ETA: 2s - rpn_cls: 2.3160 - rpn_regr: 0.1159 - detector_cls: 1.9205 - detector_regr: 0.4536Average number of overlapping bounding boxes from RPN = 19.273333333333333 for 150 previous iterations
# 150/150 [==============================] - 39s 259ms/step - rpn_cls: 2.3033 - rpn_regr: 0.1165 - detector_cls: 1.9161 - detector_regr: 0.4521
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.927152317880793
# Classifier accuracy for bounding boxes from RPN: 0.5333333333333333
# Loss RPN classifier: 2.120969391729526
# Loss RPN regression: 0.12708125164421896
# Loss Detector classifier: 1.867024559925
# Loss Detector regression: 0.43550194104512535
# Elapsed time: 41.59874248504639[s]
# Epoch 12/100
#  51/150 [=========>....................] - ETA: 24s - rpn_cls: 1.5765 - rpn_regr: 0.0927 - detector_cls: 1.9618 - detector_regr: 0.5010Exception: 'NoneType' object is not subscriptable
# 138/150 [==========================>...] - ETA: 2s - rpn_cls: 1.6695 - rpn_regr: 0.0997 - detector_cls: 1.9294 - detector_regr: 0.4722Average number of overlapping bounding boxes from RPN = 21.053333333333335 for 150 previous iterations
# 150/150 [==============================] - 37s 246ms/step - rpn_cls: 1.6760 - rpn_regr: 0.1002 - detector_cls: 1.9264 - detector_regr: 0.4701
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.483443708609272
# Classifier accuracy for bounding boxes from RPN: 0.5316666666666666
# Loss RPN classifier: 1.764840455968418
# Loss RPN regression: 0.10630160100913297
# Loss Detector classifier: 1.8928004413843156
# Loss Detector regression: 0.4421363525589307
# Elapsed time: 37.10808348655701[s]
# Epoch 13/100
# 137/150 [==========================>...] - ETA: 3s - rpn_cls: 1.7981 - rpn_regr: 0.1017 - detector_cls: 1.9610 - detector_regr: 0.4292Average number of overlapping bounding boxes from RPN = 21.126666666666665 for 150 previous iterations
# 150/150 [==============================] - 40s 265ms/step - rpn_cls: 1.7970 - rpn_regr: 0.1020 - detector_cls: 1.9569 - detector_regr: 0.4307
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.23841059602649
# Classifier accuracy for bounding boxes from RPN: 0.525
# Loss RPN classifier: 1.788543974237369
# Loss RPN regression: 0.10421668849885464
# Loss Detector classifier: 1.9079457088311513
# Loss Detector regression: 0.443645366281271
# Elapsed time: 39.95019316673279[s]
# Epoch 14/100
#  61/150 [===========>..................] - ETA: 21s - rpn_cls: 2.0473 - rpn_regr: 0.1103 - detector_cls: 1.9196 - detector_regr: 0.3942Exception: 'NoneType' object is not subscriptable
# 136/150 [==========================>...] - ETA: 3s - rpn_cls: 2.3120 - rpn_regr: 0.1087 - detector_cls: 1.8363 - detector_regr: 0.4073Average number of overlapping bounding boxes from RPN = 21.013333333333332 for 150 previous iterations
# 150/150 [==============================] - 37s 244ms/step - rpn_cls: 2.3219 - rpn_regr: 0.1082 - detector_cls: 1.8330 - detector_regr: 0.4099
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.827814569536425
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 2.4765604138476798
# Loss RPN regression: 0.10421487685292959
# Loss Detector classifier: 1.8046016913155716
# Loss Detector regression: 0.43634722302357354
# Elapsed time: 36.900901794433594[s]
# Epoch 15/100
#  25/150 [====>.........................] - ETA: 30s - rpn_cls: 2.8655 - rpn_regr: 0.0920 - detector_cls: 1.7916 - detector_regr: 0.4648Exception: 'NoneType' object is not subscriptable
# 130/150 [=========================>....] - ETA: 4s - rpn_cls: 2.5977 - rpn_regr: 0.1055 - detector_cls: 1.7864 - detector_regr: 0.4509Exception: 'NoneType' object is not subscriptable
# 135/150 [==========================>...] - ETA: 3s - rpn_cls: 2.5907 - rpn_regr: 0.1057 - detector_cls: 1.7857 - detector_regr: 0.4499Average number of overlapping bounding boxes from RPN = 20.706666666666667 for 150 previous iterations
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 2.5663 - rpn_regr: 0.1061 - detector_cls: 1.7852 - detector_regr: 0.4475
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.894039735099337
# Classifier accuracy for bounding boxes from RPN: 0.5433333333333333
# Loss RPN classifier: 2.323583013922007
# Loss RPN regression: 0.10834924191236496
# Loss Detector classifier: 1.7838039628664653
# Loss Detector regression: 0.42366909484068555
# Elapsed time: 37.420663833618164[s]
# Epoch 16/100
#  33/150 [=====>........................] - ETA: 27s - rpn_cls: 1.5023 - rpn_regr: 0.1067 - detector_cls: 1.8026 - detector_regr: 0.4727Exception: 'NoneType' object is not subscriptable
# 134/150 [=========================>....] - ETA: 3s - rpn_cls: 2.3792 - rpn_regr: 0.1062 - detector_cls: 1.8394 - detector_regr: 0.4385Average number of overlapping bounding boxes from RPN = 22.8 for 150 previous iterations
# 150/150 [==============================] - 37s 249ms/step - rpn_cls: 2.3681 - rpn_regr: 0.1059 - detector_cls: 1.8393 - detector_regr: 0.4365
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.344370860927153
# Classifier accuracy for bounding boxes from RPN: 0.5183333333333333
# Loss RPN classifier: 2.2992926403826868
# Loss RPN regression: 0.10178634371608496
# Loss Detector classifier: 1.831373000741005
# Loss Detector regression: 0.41735225811600685
# Elapsed time: 37.576889991760254[s]
# Epoch 17/100
#  25/150 [====>.........................] - ETA: 30s - rpn_cls: 1.5715 - rpn_regr: 0.0846 - detector_cls: 2.0344 - detector_regr: 0.4309Exception: 'NoneType' object is not subscriptable
# 133/150 [=========================>....] - ETA: 4s - rpn_cls: 2.0722 - rpn_regr: 0.0900 - detector_cls: 1.8245 - detector_regr: 0.4119Average number of overlapping bounding boxes from RPN = 21.106666666666666 for 150 previous iterations
# 150/150 [==============================] - 38s 250ms/step - rpn_cls: 2.0613 - rpn_regr: 0.0909 - detector_cls: 1.8237 - detector_regr: 0.4104
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.165562913907284
# Classifier accuracy for bounding boxes from RPN: 0.5266666666666666
# Loss RPN classifier: 2.0109019261716465
# Loss RPN regression: 0.0984645880262057
# Loss Detector classifier: 1.8149710716803868
# Loss Detector regression: 0.398638227134943
# Elapsed time: 37.76086664199829[s]
# Epoch 18/100
#   8/150 [>.............................] - ETA: 35s - rpn_cls: 5.7805 - rpn_regr: 0.0812 - detector_cls: 1.4770 - detector_regr: 0.3165Exception: 'NoneType' object is not subscriptable
#  99/150 [==================>...........] - ETA: 12s - rpn_cls: 2.6441 - rpn_regr: 0.0941 - detector_cls: 1.7217 - detector_regr: 0.4013Exception: 'NoneType' object is not subscriptable
# 132/150 [=========================>....] - ETA: 4s - rpn_cls: 2.4880 - rpn_regr: 0.0951 - detector_cls: 1.7349 - detector_regr: 0.3975Average number of overlapping bounding boxes from RPN = 21.573333333333334 for 150 previous iterations
# 150/150 [==============================] - 38s 250ms/step - rpn_cls: 2.4250 - rpn_regr: 0.0957 - detector_cls: 1.7396 - detector_regr: 0.3954
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.337748344370862
# Classifier accuracy for bounding boxes from RPN: 0.5316666666666666
# Loss RPN classifier: 1.9151563520740773
# Loss RPN regression: 0.10035808524116874
# Loss Detector classifier: 1.7761867060263952
# Loss Detector regression: 0.3782892512281736
# Elapsed time: 37.78630614280701[s]
# Epoch 19/100
# 131/150 [=========================>....] - ETA: 4s - rpn_cls: 2.4808 - rpn_regr: 0.0930 - detector_cls: 1.6225 - detector_regr: 0.3887Average number of overlapping bounding boxes from RPN = 22.566666666666666 for 150 previous iterations
# 150/150 [==============================] - 37s 246ms/step - rpn_cls: 2.4309 - rpn_regr: 0.0936 - detector_cls: 1.6275 - detector_regr: 0.3886
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.24503311258278
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 2.045707269284199
# Loss RPN regression: 0.10022800545518597
# Loss Detector classifier: 1.6512872589627903
# Loss Detector regression: 0.3848977347215017
# Elapsed time: 37.09282732009888[s]
# Epoch 20/100
# 130/150 [=========================>....] - ETA: 4s - rpn_cls: 1.5591 - rpn_regr: 0.1089 - detector_cls: 1.6932 - detector_regr: 0.3568Average number of overlapping bounding boxes from RPN = 21.02 for 150 previous iterations
# 150/150 [==============================] - 37s 246ms/step - rpn_cls: 1.5875 - rpn_regr: 0.1090 - detector_cls: 1.6967 - detector_regr: 0.3590
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.86092715231788
# Classifier accuracy for bounding boxes from RPN: 0.5483333333333333
# Loss RPN classifier: 1.7717639028753809
# Loss RPN regression: 0.10964757232616346
# Loss Detector classifier: 1.7056577161699533
# Loss Detector regression: 0.3727890476087729
# Elapsed time: 37.128783226013184[s]
# Total loss decreased from 4.021980460868499 to 3.959858238980271, saving weights
# Epoch 21/100
# 129/150 [========================>.....] - ETA: 5s - rpn_cls: 1.8531 - rpn_regr: 0.1137 - detector_cls: 1.7088 - detector_regr: 0.3672Average number of overlapping bounding boxes from RPN = 22.013333333333332 for 150 previous iterations
# 150/150 [==============================] - 37s 249ms/step - rpn_cls: 1.8772 - rpn_regr: 0.1143 - detector_cls: 1.7151 - detector_regr: 0.3677
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.198675496688743
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 2.0181513362075383
# Loss RPN regression: 0.11673426495244106
# Loss Detector classifier: 1.7602014601230622
# Loss Detector regression: 0.36925387889146805
# Elapsed time: 40.19834613800049[s]
# Epoch 22/100
#  39/150 [======>.......................] - ETA: 27s - rpn_cls: 2.1834 - rpn_regr: 0.1116 - detector_cls: 1.6770 - detector_regr: 0.3472Exception: 'NoneType' object is not subscriptable
#  90/150 [=================>............] - ETA: 14s - rpn_cls: 2.2710 - rpn_regr: 0.1112 - detector_cls: 1.7001 - detector_regr: 0.3642Exception: 'NoneType' object is not subscriptable
#  96/150 [==================>...........] - ETA: 13s - rpn_cls: 2.2781 - rpn_regr: 0.1111 - detector_cls: 1.6997 - detector_regr: 0.3644Exception: 'NoneType' object is not subscriptable
# 128/150 [========================>.....] - ETA: 5s - rpn_cls: 2.2783 - rpn_regr: 0.1102 - detector_cls: 1.7049 - detector_regr: 0.3677Average number of overlapping bounding boxes from RPN = 22.953333333333333 for 150 previous iterations
# 150/150 [==============================] - 37s 249ms/step - rpn_cls: 2.2625 - rpn_regr: 0.1104 - detector_cls: 1.7095 - detector_regr: 0.3703
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.039735099337747
# Classifier accuracy for bounding boxes from RPN: 0.5316666666666666
# Loss RPN classifier: 2.1852136598979994
# Loss RPN regression: 0.11404672961371641
# Loss Detector classifier: 1.7411376572648685
# Loss Detector regression: 0.39203604370355605
# Elapsed time: 37.63700294494629[s]
# Epoch 23/100
# 127/150 [========================>.....] - ETA: 5s - rpn_cls: 3.0023 - rpn_regr: 0.0865 - detector_cls: 1.6659 - detector_regr: 0.3715Average number of overlapping bounding boxes from RPN = 22.06 for 150 previous iterations
# 150/150 [==============================] - 37s 245ms/step - rpn_cls: 2.9055 - rpn_regr: 0.0884 - detector_cls: 1.6707 - detector_regr: 0.3698
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.841059602649008
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 2.3334116266595455
# Loss RPN regression: 0.0979243323354361
# Loss Detector classifier: 1.696860139966011
# Loss Detector regression: 0.36052985072135924
# Elapsed time: 36.94354605674744[s]
# Epoch 24/100
#  58/150 [==========>...................] - ETA: 24s - rpn_cls: 1.9032 - rpn_regr: 0.1117 - detector_cls: 1.6412 - detector_regr: 0.3983Exception: 'NoneType' object is not subscriptable
# 126/150 [========================>.....] - ETA: 6s - rpn_cls: 1.9967 - rpn_regr: 0.1094 - detector_cls: 1.6521 - detector_regr: 0.3778Average number of overlapping bounding boxes from RPN = 22.80666666666667 for 150 previous iterations
# 150/150 [==============================] - 41s 272ms/step - rpn_cls: 1.9990 - rpn_regr: 0.1085 - detector_cls: 1.6569 - detector_regr: 0.3766
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.874172185430464
# Classifier accuracy for bounding boxes from RPN: 0.525
# Loss RPN classifier: 2.0422178139378473
# Loss RPN regression: 0.10387753447517753
# Loss Detector classifier: 1.7010590600967408
# Loss Detector regression: 0.37119764449695747
# Elapsed time: 41.083887338638306[s]
# Epoch 25/100
#  63/150 [===========>..................] - ETA: 21s - rpn_cls: 3.1336 - rpn_regr: 0.1100 - detector_cls: 1.7329 - detector_regr: 0.3679Exception: 'NoneType' object is not subscriptable
# 125/150 [========================>.....] - ETA: 6s - rpn_cls: 2.7193 - rpn_regr: 0.1056 - detector_cls: 1.7064 - detector_regr: 0.3577Average number of overlapping bounding boxes from RPN = 23.086666666666666 for 150 previous iterations
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 2.5986 - rpn_regr: 0.1055 - detector_cls: 1.7002 - detector_regr: 0.3570
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.70198675496689
# Classifier accuracy for bounding boxes from RPN: 0.5266666666666666
# Loss RPN classifier: 1.920865059595217
# Loss RPN regression: 0.10857396805969377
# Loss Detector classifier: 1.675709981918335
# Loss Detector regression: 0.3564780454834302
# Elapsed time: 37.45287322998047[s]
# Epoch 26/100
# 124/150 [=======================>......] - ETA: 6s - rpn_cls: 1.0238 - rpn_regr: 0.1236 - detector_cls: 1.7724 - detector_regr: 0.3683Average number of overlapping bounding boxes from RPN = 24.313333333333333 for 150 previous iterations
# 150/150 [==============================] - 38s 251ms/step - rpn_cls: 1.0811 - rpn_regr: 0.1234 - detector_cls: 1.7708 - detector_regr: 0.3697
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.158940397350992
# Classifier accuracy for bounding boxes from RPN: 0.5266666666666666
# Loss RPN classifier: 1.4183048897089812
# Loss RPN regression: 0.12164844042931994
# Loss Detector classifier: 1.7510978270570436
# Loss Detector regression: 0.3785298086206118
# Elapsed time: 37.931634187698364[s]
# Total loss decreased from 3.959858238980271 to 3.6695809658159564, saving weights
# Epoch 27/100
#  18/150 [==>...........................] - ETA: 33s - rpn_cls: 1.2217 - rpn_regr: 0.1141 - detector_cls: 1.9035 - detector_regr: 0.4976Exception: 'NoneType' object is not subscriptable
#  25/150 [====>.........................] - ETA: 32s - rpn_cls: 1.3715 - rpn_regr: 0.1125 - detector_cls: 1.8940 - detector_regr: 0.4768Exception: 'NoneType' object is not subscriptable
#  67/150 [============>.................] - ETA: 21s - rpn_cls: 1.7205 - rpn_regr: 0.1154 - detector_cls: 1.8307 - detector_regr: 0.4191Exception: 'NoneType' object is not subscriptable
# 123/150 [=======================>......] - ETA: 6s - rpn_cls: 1.7241 - rpn_regr: 0.1183 - detector_cls: 1.8025 - detector_regr: 0.4053Average number of overlapping bounding boxes from RPN = 20.38 for 150 previous iterations
# 150/150 [==============================] - 38s 252ms/step - rpn_cls: 1.6973 - rpn_regr: 0.1191 - detector_cls: 1.8129 - detector_regr: 0.4034
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.90728476821192
# Classifier accuracy for bounding boxes from RPN: 0.5433333333333333
# Loss RPN classifier: 1.5505626211534378
# Loss RPN regression: 0.12268249771247307
# Loss Detector classifier: 1.859319561123848
# Loss Detector regression: 0.39002044866482416
# Elapsed time: 40.536768674850464[s]
# Epoch 28/100
# 122/150 [=======================>......] - ETA: 6s - rpn_cls: 2.3880 - rpn_regr: 0.1077 - detector_cls: 1.8084 - detector_regr: 0.3548Average number of overlapping bounding boxes from RPN = 21.333333333333332 for 150 previous iterations
# 140/150 [===========================>..] - ETA: 2s - rpn_cls: 2.3928 - rpn_regr: 0.1081 - detector_cls: 1.7968 - detector_regr: 0.3569Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 2.3926 - rpn_regr: 0.1082 - detector_cls: 1.7897 - detector_regr: 0.3575
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.960264900662253
# Classifier accuracy for bounding boxes from RPN: 0.555
# Loss RPN classifier: 2.3535936783285276
# Loss RPN regression: 0.11007876708482703
# Loss Detector classifier: 1.68285353799661
# Loss Detector regression: 0.36650371278325716
# Elapsed time: 37.49716854095459[s]
# Epoch 29/100
#   3/150 [..............................] - ETA: 35s - rpn_cls: 4.7180 - rpn_regr: 0.0498 - detector_cls: 2.0520 - detector_regr: 0.3994Exception: 'NoneType' object is not subscriptable
#  91/150 [=================>............] - ETA: 14s - rpn_cls: 2.1791 - rpn_regr: 0.1258 - detector_cls: 1.6771 - detector_regr: 0.3548Exception: 'NoneType' object is not subscriptable
# 121/150 [=======================>......] - ETA: 7s - rpn_cls: 2.1798 - rpn_regr: 0.1227 - detector_cls: 1.6789 - detector_regr: 0.3509Average number of overlapping bounding boxes from RPN = 20.34 for 150 previous iterations
# 150/150 [==============================] - 37s 245ms/step - rpn_cls: 2.1767 - rpn_regr: 0.1216 - detector_cls: 1.6803 - detector_regr: 0.3496
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.344370860927153
# Classifier accuracy for bounding boxes from RPN: 0.535
# Loss RPN classifier: 2.1664812148137913
# Loss RPN regression: 0.11700232833623886
# Loss Detector classifier: 1.6995295272270838
# Loss Detector regression: 0.34844424804051716
# Elapsed time: 37.03532338142395[s]
# Epoch 30/100
# 120/150 [=======================>......] - ETA: 7s - rpn_cls: 1.7771 - rpn_regr: 0.0980 - detector_cls: 1.8188 - detector_regr: 0.4134Average number of overlapping bounding boxes from RPN = 21.69333333333333 for 150 previous iterations
# 150/150 [==============================] - 39s 257ms/step - rpn_cls: 1.7892 - rpn_regr: 0.0980 - detector_cls: 1.7997 - detector_regr: 0.4086
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.91390728476821
# Classifier accuracy for bounding boxes from RPN: 0.5233333333333333
# Loss RPN classifier: 1.791575254547525
# Loss RPN regression: 0.0966055753082037
# Loss Detector classifier: 1.7209550440311432
# Loss Detector regression: 0.38312326177954675
# Elapsed time: 38.78432559967041[s]
# Epoch 31/100
#  26/150 [====>.........................] - ETA: 30s - rpn_cls: 1.7807 - rpn_regr: 0.1534 - detector_cls: 1.6771 - detector_regr: 0.3478Exception: 'NoneType' object is not subscriptable
#  89/150 [================>.............] - ETA: 14s - rpn_cls: 1.9633 - rpn_regr: 0.1253 - detector_cls: 1.7168 - detector_regr: 0.3450Exception: 'NoneType' object is not subscriptable
# 119/150 [======================>.......] - ETA: 7s - rpn_cls: 1.9277 - rpn_regr: 0.1204 - detector_cls: 1.7171 - detector_regr: 0.3475Average number of overlapping bounding boxes from RPN = 20.153333333333332 for 150 previous iterations
# 150/150 [==============================] - 37s 245ms/step - rpn_cls: 1.9133 - rpn_regr: 0.1176 - detector_cls: 1.7163 - detector_regr: 0.3477
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.85430463576159
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 1.9906563729578193
# Loss RPN regression: 0.10503769651055336
# Loss Detector classifier: 1.7253293577829998
# Loss Detector regression: 0.3465041168530782
# Elapsed time: 37.027926445007324[s]
# Epoch 32/100
# 118/150 [======================>.......] - ETA: 7s - rpn_cls: 1.3712 - rpn_regr: 0.0799 - detector_cls: 1.5885 - detector_regr: 0.3470Average number of overlapping bounding boxes from RPN = 22.28 for 150 previous iterations
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 1.4561 - rpn_regr: 0.0827 - detector_cls: 1.6008 - detector_regr: 0.3436
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.278145695364238
# Classifier accuracy for bounding boxes from RPN: 0.5516666666666666
# Loss RPN classifier: 1.7688978704587366
# Loss RPN regression: 0.09168898478616029
# Loss Detector classifier: 1.6438518039882184
# Loss Detector regression: 0.33647229584554833
# Elapsed time: 37.46142554283142[s]
# Epoch 33/100
# 117/150 [======================>.......] - ETA: 8s - rpn_cls: 1.8538 - rpn_regr: 0.1054 - detector_cls: 1.7426 - detector_regr: 0.3935Average number of overlapping bounding boxes from RPN = 24.213333333333335 for 150 previous iterations
# 150/150 [==============================] - 40s 266ms/step - rpn_cls: 1.8781 - rpn_regr: 0.1049 - detector_cls: 1.7223 - detector_regr: 0.3897
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.841059602649008
# Classifier accuracy for bounding boxes from RPN: 0.5383333333333333
# Loss RPN classifier: 1.9875100583970058
# Loss RPN regression: 0.10117449755159517
# Loss Detector classifier: 1.650527102947235
# Loss Detector regression: 0.3665640157088637
# Elapsed time: 40.1073043346405[s]
# Epoch 34/100
# 116/150 [======================>.......] - ETA: 8s - rpn_cls: 2.1503 - rpn_regr: 0.0903 - detector_cls: 1.6166 - detector_regr: 0.2977Average number of overlapping bounding boxes from RPN = 22.426666666666666 for 150 previous iterations
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 2.1637 - rpn_regr: 0.0914 - detector_cls: 1.6155 - detector_regr: 0.3028
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.37748344370861
# Classifier accuracy for bounding boxes from RPN: 0.57
# Loss RPN classifier: 2.2873070868004866
# Loss RPN regression: 0.0960287483719488
# Loss Detector classifier: 1.5879773904879888
# Loss Detector regression: 0.3125646944716573
# Elapsed time: 37.45038819313049[s]
# Epoch 35/100
# 115/150 [======================>.......] - ETA: 8s - rpn_cls: 2.4280 - rpn_regr: 0.0798 - detector_cls: 1.5817 - detector_regr: 0.3385Average number of overlapping bounding boxes from RPN = 21.046666666666667 for 150 previous iterations
# 129/150 [========================>.....] - ETA: 5s - rpn_cls: 2.4181 - rpn_regr: 0.0814 - detector_cls: 1.5836 - detector_regr: 0.3406Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 252ms/step - rpn_cls: 2.3867 - rpn_regr: 0.0838 - detector_cls: 1.5858 - detector_regr: 0.3436
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.450331125827816
# Classifier accuracy for bounding boxes from RPN: 0.55
# Loss RPN classifier: 2.244462438039734
# Loss RPN regression: 0.10107536257555087
# Loss Detector classifier: 1.603088510632515
# Loss Detector regression: 0.3591727744539579
# Elapsed time: 38.04143929481506[s]
# Epoch 36/100
#  21/150 [===>..........................] - ETA: 32s - rpn_cls: 1.6831 - rpn_regr: 0.1111 - detector_cls: 1.4357 - detector_regr: 0.2606Exception: 'NoneType' object is not subscriptable
#  31/150 [=====>........................] - ETA: 30s - rpn_cls: 1.6982 - rpn_regr: 0.1104 - detector_cls: 1.4810 - detector_regr: 0.2653Exception: 'NoneType' object is not subscriptable
#  37/150 [======>.......................] - ETA: 28s - rpn_cls: 1.6812 - rpn_regr: 0.1098 - detector_cls: 1.4982 - detector_regr: 0.2672Exception: 'NoneType' object is not subscriptable
# 114/150 [=====================>........] - ETA: 9s - rpn_cls: 1.7117 - rpn_regr: 0.1128 - detector_cls: 1.5705 - detector_regr: 0.3067Average number of overlapping bounding boxes from RPN = 23.28 for 150 previous iterations
# 150/150 [==============================] - 39s 259ms/step - rpn_cls: 1.7016 - rpn_regr: 0.1154 - detector_cls: 1.5776 - detector_regr: 0.3157
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.662251655629138
# Classifier accuracy for bounding boxes from RPN: 0.5516666666666666
# Loss RPN classifier: 1.7053518064349633
# Loss RPN regression: 0.12784728091210126
# Loss Detector classifier: 1.6101893116037052
# Loss Detector regression: 0.3436133347203334
# Elapsed time: 39.02364492416382[s]
# Epoch 37/100
#  96/150 [==================>...........] - ETA: 13s - rpn_cls: 0.9276 - rpn_regr: 0.1317 - detector_cls: 1.6092 - detector_regr: 0.3814Exception: 'NoneType' object is not subscriptable
# 112/150 [=====================>........] - ETA: 9s - rpn_cls: 0.9820 - rpn_regr: 0.1287 - detector_cls: 1.6154 - detector_regr: 0.3791Exception: 'NoneType' object is not subscriptable
# 113/150 [=====================>........] - ETA: 9s - rpn_cls: 0.9848 - rpn_regr: 0.1286 - detector_cls: 1.6157 - detector_regr: 0.3789Average number of overlapping bounding boxes from RPN = 24.726666666666667 for 150 previous iterations
# 123/150 [=======================>......] - ETA: 6s - rpn_cls: 1.0107 - rpn_regr: 0.1272 - detector_cls: 1.6198 - detector_regr: 0.3775Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 256ms/step - rpn_cls: 1.0553 - rpn_regr: 0.1242 - detector_cls: 1.6260 - detector_regr: 0.3730
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 25.728476821192054
# Classifier accuracy for bounding boxes from RPN: 0.5283333333333333
# Loss RPN classifier: 1.2349040980093464
# Loss RPN regression: 0.1088619657047093
# Loss Detector classifier: 1.6607342676321666
# Loss Detector regression: 0.3427901470909516
# Elapsed time: 38.654616594314575[s]
# Total loss decreased from 3.6695809658159564 to 3.3472904784371744, saving weights
# Epoch 38/100
#  28/150 [====>.........................] - ETA: 31s - rpn_cls: 0.8407 - rpn_regr: 0.1156 - detector_cls: 1.7080 - detector_regr: 0.2945Exception: 'NoneType' object is not subscriptable
#  30/150 [=====>........................] - ETA: 31s - rpn_cls: 0.8640 - rpn_regr: 0.1151 - detector_cls: 1.6943 - detector_regr: 0.2960Exception: 'NoneType' object is not subscriptable
#  59/150 [==========>...................] - ETA: 23s - rpn_cls: 1.1103 - rpn_regr: 0.1141 - detector_cls: 1.6247 - detector_regr: 0.3090Exception: 'NoneType' object is not subscriptable
# 112/150 [=====================>........] - ETA: 9s - rpn_cls: 1.1532 - rpn_regr: 0.1142 - detector_cls: 1.6178 - detector_regr: 0.3271 Average number of overlapping bounding boxes from RPN = 23.85333333333333 for 150 previous iterations
# 150/150 [==============================] - 39s 259ms/step - rpn_cls: 1.1455 - rpn_regr: 0.1145 - detector_cls: 1.6133 - detector_regr: 0.3353
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.807947019867548
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 1.210736341650667
# Loss RPN regression: 0.1148926742747426
# Loss Detector classifier: 1.604485869606336
# Loss Detector regression: 0.35990843042731285
# Elapsed time: 41.846150159835815[s]
# Total loss decreased from 3.3472904784371744 to 3.290023315959058, saving weights
# Epoch 39/100
# 111/150 [=====================>........] - ETA: 10s - rpn_cls: 1.6493 - rpn_regr: 0.1091 - detector_cls: 1.7689 - detector_regr: 0.3950Average number of overlapping bounding boxes from RPN = 22.093333333333334 for 150 previous iterations
# 150/150 [==============================] - 41s 271ms/step - rpn_cls: 1.5881 - rpn_regr: 0.1110 - detector_cls: 1.7472 - detector_regr: 0.3903
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.417218543046356
# Classifier accuracy for bounding boxes from RPN: 0.5283333333333333
# Loss RPN classifier: 1.4063236069114977
# Loss RPN regression: 0.12069147240370512
# Loss Detector classifier: 1.674339737991492
# Loss Detector regression: 0.37121263646831115
# Elapsed time: 43.42893934249878[s]
# Epoch 40/100
#  42/150 [=======>......................] - ETA: 26s - rpn_cls: 1.9581 - rpn_regr: 0.1203 - detector_cls: 1.4879 - detector_regr: 0.3541Exception: 'NoneType' object is not subscriptable
#  62/150 [===========>..................] - ETA: 22s - rpn_cls: 1.8254 - rpn_regr: 0.1217 - detector_cls: 1.5046 - detector_regr: 0.3528Exception: 'NoneType' object is not subscriptable
# 110/150 [=====================>........] - ETA: 10s - rpn_cls: 1.8102 - rpn_regr: 0.1200 - detector_cls: 1.5226 - detector_regr: 0.3500Average number of overlapping bounding boxes from RPN = 23.613333333333333 for 150 previous iterations
# 138/150 [==========================>...] - ETA: 3s - rpn_cls: 1.8282 - rpn_regr: 0.1203 - detector_cls: 1.5317 - detector_regr: 0.3492Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 39s 258ms/step - rpn_cls: 1.8301 - rpn_regr: 0.1204 - detector_cls: 1.5351 - detector_regr: 0.3487
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.70198675496689
# Classifier accuracy for bounding boxes from RPN: 0.5466666666666666
# Loss RPN classifier: 1.8091802265944883
# Loss RPN regression: 0.1214339275782307
# Loss Detector classifier: 1.567538672685623
# Loss Detector regression: 0.33876718814174334
# Elapsed time: 38.8834171295166[s]
# Epoch 41/100
#  23/150 [===>..........................] - ETA: 31s - rpn_cls: 0.8923 - rpn_regr: 0.0854 - detector_cls: 1.4024 - detector_regr: 0.2455Exception: 'NoneType' object is not subscriptable
# 109/150 [====================>.........] - ETA: 10s - rpn_cls: 1.3845 - rpn_regr: 0.1093 - detector_cls: 1.4592 - detector_regr: 0.3018Average number of overlapping bounding boxes from RPN = 21.933333333333334 for 150 previous iterations
# 119/150 [======================>.......] - ETA: 7s - rpn_cls: 1.4131 - rpn_regr: 0.1093 - detector_cls: 1.4652 - detector_regr: 0.3046Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 37s 247ms/step - rpn_cls: 1.4857 - rpn_regr: 0.1095 - detector_cls: 1.4743 - detector_regr: 0.3112
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.496688741721854
# Classifier accuracy for bounding boxes from RPN: 0.5666666666666667
# Loss RPN classifier: 1.715641392018883
# Loss RPN regression: 0.11134755483518044
# Loss Detector classifier: 1.4928610028823217
# Loss Detector regression: 0.34341634158045053
# Elapsed time: 37.300326347351074[s]
# Epoch 42/100
#  58/150 [==========>...................] - ETA: 22s - rpn_cls: 2.4619 - rpn_regr: 0.0904 - detector_cls: 1.6515 - detector_regr: 0.3550Exception: 'NoneType' object is not subscriptable
# 108/150 [====================>.........] - ETA: 10s - rpn_cls: 2.3051 - rpn_regr: 0.1001 - detector_cls: 1.6101 - detector_regr: 0.3588Average number of overlapping bounding boxes from RPN = 21.026666666666667 for 150 previous iterations
# 150/150 [==============================] - 38s 253ms/step - rpn_cls: 2.2196 - rpn_regr: 0.1038 - detector_cls: 1.5961 - detector_regr: 0.3551
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.403973509933774
# Classifier accuracy for bounding boxes from RPN: 0.5683333333333334
# Loss RPN classifier: 1.8663259106122358
# Loss RPN regression: 0.11385818428049485
# Loss Detector classifier: 1.5539453989267349
# Loss Detector regression: 0.3458412624150515
# Elapsed time: 38.1221387386322[s]
# Epoch 43/100
#  15/150 [==>...........................] - ETA: 32s - rpn_cls: 0.5884 - rpn_regr: 0.1392 - detector_cls: 1.5051 - detector_regr: 0.4043Exception: 'NoneType' object is not subscriptable
# Exception: 'NoneType' object is not subscriptable
# 107/150 [====================>.........] - ETA: 10s - rpn_cls: 1.1548 - rpn_regr: 0.1251 - detector_cls: 1.3955 - detector_regr: 0.3484Average number of overlapping bounding boxes from RPN = 22.2 for 150 previous iterations
# 116/150 [======================>.......] - ETA: 8s - rpn_cls: 1.1786 - rpn_regr: 0.1248 - detector_cls: 1.3932 - detector_regr: 0.3473Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 254ms/step - rpn_cls: 1.2532 - rpn_regr: 0.1244 - detector_cls: 1.3806 - detector_regr: 0.3442
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.24503311258278
# Classifier accuracy for bounding boxes from RPN: 0.615
# Loss RPN classifier: 1.6003985654158681
# Loss RPN regression: 0.12262684298679233
# Loss Detector classifier: 1.3305977392196655
# Loss Detector regression: 0.33888249556223554
# Elapsed time: 38.37416744232178[s]
# Epoch 44/100
#  68/150 [============>.................] - ETA: 20s - rpn_cls: 1.9562 - rpn_regr: 0.1205 - detector_cls: 1.6621 - detector_regr: 0.3550Exception: 'NoneType' object is not subscriptable
#  85/150 [================>.............] - ETA: 16s - rpn_cls: 1.9114 - rpn_regr: 0.1180 - detector_cls: 1.6360 - detector_regr: 0.3514Exception: 'NoneType' object is not subscriptable
# 101/150 [===================>..........] - ETA: 12s - rpn_cls: 1.9065 - rpn_regr: 0.1160 - detector_cls: 1.6229 - detector_regr: 0.3484Exception: 'NoneType' object is not subscriptable
# 106/150 [====================>.........] - ETA: 11s - rpn_cls: 1.9043 - rpn_regr: 0.1154 - detector_cls: 1.6198 - detector_regr: 0.3474Average number of overlapping bounding boxes from RPN = 22.013333333333332 for 150 previous iterations
# 123/150 [=======================>......] - ETA: 6s - rpn_cls: 1.8880 - rpn_regr: 0.1138 - detector_cls: 1.6072 - detector_regr: 0.3451Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 251ms/step - rpn_cls: 1.8659 - rpn_regr: 0.1118 - detector_cls: 1.5996 - detector_regr: 0.3453
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.04635761589404
# Classifier accuracy for bounding boxes from RPN: 0.555
# Loss RPN classifier: 1.6785512632349386
# Loss RPN regression: 0.09939651756857833
# Loss Detector classifier: 1.5631754678487777
# Loss Detector regression: 0.3459637689838807
# Elapsed time: 37.974374294281006[s]
# Epoch 45/100
#  79/150 [==============>...............] - ETA: 17s - rpn_cls: 1.3528 - rpn_regr: 0.1044 - detector_cls: 1.4728 - detector_regr: 0.3323Exception: 'NoneType' object is not subscriptable
# 105/150 [====================>.........] - ETA: 11s - rpn_cls: 1.3870 - rpn_regr: 0.1038 - detector_cls: 1.4884 - detector_regr: 0.3330Average number of overlapping bounding boxes from RPN = 24.826666666666668 for 150 previous iterations
# 150/150 [==============================] - 38s 252ms/step - rpn_cls: 1.3878 - rpn_regr: 0.1038 - detector_cls: 1.5283 - detector_regr: 0.3356
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.09933774834437
# Classifier accuracy for bounding boxes from RPN: 0.5583333333333333
# Loss RPN classifier: 1.3888386747839425
# Loss RPN regression: 0.10164343901289007
# Loss Detector classifier: 1.6634435560305914
# Loss Detector regression: 0.34797780292729535
# Elapsed time: 37.953781604766846[s]
# Epoch 46/100
#  73/150 [=============>................] - ETA: 19s - rpn_cls: 0.9876 - rpn_regr: 0.1068 - detector_cls: 1.6260 - detector_regr: 0.3733Exception: 'NoneType' object is not subscriptable
# 104/150 [===================>..........] - ETA: 11s - rpn_cls: 1.1838 - rpn_regr: 0.1048 - detector_cls: 1.5833 - detector_regr: 0.3577Average number of overlapping bounding boxes from RPN = 23.58 for 150 previous iterations
# 118/150 [======================>.......] - ETA: 8s - rpn_cls: 1.2487 - rpn_regr: 0.1045 - detector_cls: 1.5744 - detector_regr: 0.3552Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 254ms/step - rpn_cls: 1.3506 - rpn_regr: 0.1043 - detector_cls: 1.5625 - detector_regr: 0.3521
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.072847682119207
# Classifier accuracy for bounding boxes from RPN: 0.5916666666666667
# Loss RPN classifier: 1.7099952189222352
# Loss RPN regression: 0.10277395281319816
# Loss Detector classifier: 1.4977708848317464
# Loss Detector regression: 0.33300599100689093
# Elapsed time: 38.33092999458313[s]
# Epoch 47/100
# 103/150 [===================>..........] - ETA: 11s - rpn_cls: 1.1691 - rpn_regr: 0.1074 - detector_cls: 1.4793 - detector_regr: 0.3934Average number of overlapping bounding boxes from RPN = 23.626666666666665 for 150 previous iterations
# 150/150 [==============================] - 37s 250ms/step - rpn_cls: 1.2231 - rpn_regr: 0.1050 - detector_cls: 1.4740 - detector_regr: 0.3808
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.258278145695364
# Classifier accuracy for bounding boxes from RPN: 0.5733333333333334
# Loss RPN classifier: 1.3721120134518214
# Loss RPN regression: 0.10674272298812866
# Loss Detector classifier: 1.4634421932697297
# Loss Detector regression: 0.3597433139632146
# Elapsed time: 37.73127627372742[s]
# Epoch 48/100
# 102/150 [===================>..........] - ETA: 12s - rpn_cls: 2.0966 - rpn_regr: 0.1081 - detector_cls: 1.5898 - detector_regr: 0.3734Average number of overlapping bounding boxes from RPN = 23.713333333333335 for 150 previous iterations
# 150/150 [==============================] - 38s 251ms/step - rpn_cls: 1.9231 - rpn_regr: 0.1082 - detector_cls: 1.5581 - detector_regr: 0.3623
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.264900662251655
# Classifier accuracy for bounding boxes from RPN: 0.5916666666666667
# Loss RPN classifier: 1.6387832807180767
# Loss RPN regression: 0.11661683370048802
# Loss Detector classifier: 1.4713788934548695
# Loss Detector regression: 0.3445626519372066
# Elapsed time: 37.954413414001465[s]
# Epoch 49/100
#   9/150 [>.............................] - ETA: 36s - rpn_cls: 0.0843 - rpn_regr: 0.0880 - detector_cls: 1.6978 - detector_regr: 0.3057Exception: 'NoneType' object is not subscriptable
# ...
# Loss RPN regression: 0.10549897868807118
# Loss Detector classifier: 1.128608198563258
# Loss Detector regression: 0.32856124445796014
# Elapsed time: 41.09650683403015[s]
# Epoch 86/100
#  64/150 [===========>..................] - ETA: 21s - rpn_cls: 1.4588 - rpn_regr: 0.1097 - detector_cls: 1.0130 - detector_regr: 0.3587Average number of overlapping bounding boxes from RPN = 21.886666666666667 for 150 previous iterations
# 130/150 [=========================>....] - ETA: 4s - rpn_cls: 1.4869 - rpn_regr: 0.1138 - detector_cls: 1.0229 - detector_regr: 0.3396Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 250ms/step - rpn_cls: 1.4857 - rpn_regr: 0.1138 - detector_cls: 1.0221 - detector_regr: 0.3353
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.14569536423841
# Classifier accuracy for bounding boxes from RPN: 0.6533333333333333
# Loss RPN classifier: 1.4136355348069685
# Loss RPN regression: 0.1135605073099335
# Loss Detector classifier: 1.0111758063733578
# Loss Detector regression: 0.30423815568288165
# Elapsed time: 37.782952547073364[s]
# Epoch 87/100
#  63/150 [===========>..................] - ETA: 21s - rpn_cls: 1.1098 - rpn_regr: 0.1138 - detector_cls: 1.2892 - detector_regr: 0.3512Average number of overlapping bounding boxes from RPN = 24.553333333333335 for 150 previous iterations
# 101/150 [===================>..........] - ETA: 12s - rpn_cls: 1.1184 - rpn_regr: 0.1080 - detector_cls: 1.2156 - detector_regr: 0.3393Exception: 'NoneType' object is not subscriptable
# 127/150 [========================>.....] - ETA: 5s - rpn_cls: 1.1091 - rpn_regr: 0.1073 - detector_cls: 1.2054 - detector_regr: 0.3351Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 250ms/step - rpn_cls: 1.1000 - rpn_regr: 0.1066 - detector_cls: 1.2023 - detector_regr: 0.3311
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.132450331125828
# Classifier accuracy for bounding boxes from RPN: 0.6566666666666666
# Loss RPN classifier: 1.1489396984042526
# Loss RPN regression: 0.10403749673937758
# Loss Detector classifier: 1.200042242705822
# Loss Detector regression: 0.3074346398065488
# Elapsed time: 37.743563652038574[s]
# Total loss decreased from 2.839381592373307 to 2.760454077656001, saving weights
# Epoch 88/100
#   2/150 [..............................] - ETA: 45s - rpn_cls: 4.8958 - rpn_regr: 0.0528 - detector_cls: 1.2848 - detector_regr: 0.1298Exception: 'NoneType' object is not subscriptable
#  48/150 [========>.....................] - ETA: 25s - rpn_cls: 2.7705 - rpn_regr: 0.1155 - detector_cls: 1.2564 - detector_regr: 0.2641Exception: 'NoneType' object is not subscriptable
#  62/150 [===========>..................] - ETA: 22s - rpn_cls: 2.6119 - rpn_regr: 0.1172 - detector_cls: 1.2459 - detector_regr: 0.2671Average number of overlapping bounding boxes from RPN = 19.546666666666667 for 150 previous iterations
#  64/150 [===========>..................] - ETA: 21s - rpn_cls: 2.5980 - rpn_regr: 0.1173 - detector_cls: 1.2442 - detector_regr: 0.2677Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 253ms/step - rpn_cls: 2.3300 - rpn_regr: 0.1142 - detector_cls: 1.1953 - detector_regr: 0.2840
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.13907284768212
# Classifier accuracy for bounding boxes from RPN: 0.6333333333333333
# Loss RPN classifier: 2.075731395077557
# Loss RPN regression: 0.10801471220950286
# Loss Detector classifier: 1.150184471110503
# Loss Detector regression: 0.31628061398863794
# Elapsed time: 40.75070667266846[s]
# Epoch 89/100
#  11/150 [=>............................] - ETA: 34s - rpn_cls: 2.0756 - rpn_regr: 0.0719 - detector_cls: 1.2425 - detector_regr: 0.4079Exception: 'NoneType' object is not subscriptable
#  14/150 [=>............................] - ETA: 35s - rpn_cls: 1.8940 - rpn_regr: 0.0767 - detector_cls: 1.1830 - detector_regr: 0.3927Exception: 'NoneType' object is not subscriptable
#  28/150 [====>.........................] - ETA: 31s - rpn_cls: 1.6946 - rpn_regr: 0.0813 - detector_cls: 1.1489 - detector_regr: 0.3472Exception: 'NoneType' object is not subscriptable
#  61/150 [===========>..................] - ETA: 23s - rpn_cls: 1.7151 - rpn_regr: 0.0922 - detector_cls: 1.1166 - detector_regr: 0.3335Average number of overlapping bounding boxes from RPN = 21.006666666666668 for 150 previous iterations
#  79/150 [==============>...............] - ETA: 18s - rpn_cls: 1.6716 - rpn_regr: 0.0960 - detector_cls: 1.1105 - detector_regr: 0.3309Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 39s 257ms/step - rpn_cls: 1.6071 - rpn_regr: 0.0996 - detector_cls: 1.1312 - detector_regr: 0.3290
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.8476821192053
# Classifier accuracy for bounding boxes from RPN: 0.6283333333333333
# Loss RPN classifier: 1.499733397990772
# Loss RPN regression: 0.10719464011490346
# Loss Detector classifier: 1.1535490334530671
# Loss Detector regression: 0.3280737270414829
# Elapsed time: 38.82410264015198[s]
# Epoch 90/100
#  19/150 [==>...........................] - ETA: 33s - rpn_cls: 1.3822 - rpn_regr: 0.1523 - detector_cls: 1.0379 - detector_regr: 0.4057Exception: 'NoneType' object is not subscriptable
#  48/150 [========>.....................] - ETA: 26s - rpn_cls: 1.7998 - rpn_regr: 0.1317 - detector_cls: 1.2184 - detector_regr: 0.3967Exception: 'NoneType' object is not subscriptable
#  60/150 [===========>..................] - ETA: 23s - rpn_cls: 1.8802 - rpn_regr: 0.1281 - detector_cls: 1.2439 - detector_regr: 0.3886Average number of overlapping bounding boxes from RPN = 19.78 for 150 previous iterations
#  91/150 [=================>............] - ETA: 15s - rpn_cls: 1.9626 - rpn_regr: 0.1227 - detector_cls: 1.2699 - detector_regr: 0.3738Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 256ms/step - rpn_cls: 2.0005 - rpn_regr: 0.1186 - detector_cls: 1.2775 - detector_regr: 0.3613
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.158940397350992
# Classifier accuracy for bounding boxes from RPN: 0.64
# Loss RPN classifier: 2.0722233424072414
# Loss RPN regression: 0.11236263461100558
# Loss Detector classifier: 1.2706055333216986
# Loss Detector regression: 0.3400677415480216
# Elapsed time: 38.71950030326843[s]
# Epoch 91/100
#  31/150 [=====>........................] - ETA: 30s - rpn_cls: 1.2339 - rpn_regr: 0.0903 - detector_cls: 1.0140 - detector_regr: 0.3440Exception: 'NoneType' object is not subscriptable
#  34/150 [=====>........................] - ETA: 30s - rpn_cls: 1.2588 - rpn_regr: 0.0914 - detector_cls: 1.0239 - detector_regr: 0.3435Exception: 'NoneType' object is not subscriptable
#  59/150 [==========>...................] - ETA: 23s - rpn_cls: 1.4200 - rpn_regr: 0.0994 - detector_cls: 1.1219 - detector_regr: 0.3439Average number of overlapping bounding boxes from RPN = 18.46 for 150 previous iterations
# 150/150 [==============================] - 39s 257ms/step - rpn_cls: 1.6023 - rpn_regr: 0.1073 - detector_cls: 1.1900 - detector_regr: 0.3394
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.32450331125828
# Classifier accuracy for bounding boxes from RPN: 0.61
# Loss RPN classifier: 1.6558215410176838
# Loss RPN regression: 0.11317301997914911
# Loss Detector classifier: 1.220360024869442
# Loss Detector regression: 0.3398180113484462
# Elapsed time: 38.765406131744385[s]
# Epoch 92/100
#  53/150 [=========>....................] - ETA: 24s - rpn_cls: 1.5572 - rpn_regr: 0.1022 - detector_cls: 1.0537 - detector_regr: 0.2778Exception: 'NoneType' object is not subscriptable
#  58/150 [==========>...................] - ETA: 23s - rpn_cls: 1.5812 - rpn_regr: 0.1026 - detector_cls: 1.0554 - detector_regr: 0.2821Average number of overlapping bounding boxes from RPN = 21.266666666666666 for 150 previous iterations
# 150/150 [==============================] - 38s 251ms/step - rpn_cls: 1.6340 - rpn_regr: 0.1060 - detector_cls: 1.0633 - detector_regr: 0.3048
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.635761589403973
# Classifier accuracy for bounding boxes from RPN: 0.6383333333333333
# Loss RPN classifier: 1.4925966639056507
# Loss RPN regression: 0.10096871872122089
# Loss Detector classifier: 1.0854808161656062
# Loss Detector regression: 0.30863788157701494
# Elapsed time: 37.84144568443298[s]
# Epoch 93/100
#  15/150 [==>...........................] - ETA: 34s - rpn_cls: 1.7537 - rpn_regr: 0.1126 - detector_cls: 1.1869 - detector_regr: 0.2657Exception: 'NoneType' object is not subscriptable
#  57/150 [==========>...................] - ETA: 23s - rpn_cls: 1.4889 - rpn_regr: 0.1119 - detector_cls: 0.9985 - detector_regr: 0.3021Average number of overlapping bounding boxes from RPN = 22.0 for 150 previous iterations
# 150/150 [==============================] - 38s 253ms/step - rpn_cls: 1.5919 - rpn_regr: 0.1095 - detector_cls: 1.0116 - detector_regr: 0.2985
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.748344370860927
# Classifier accuracy for bounding boxes from RPN: 0.6483333333333333
# Loss RPN classifier: 1.5546173156364098
# Loss RPN regression: 0.10482851375825702
# Loss Detector classifier: 1.0579874973992507
# Loss Detector regression: 0.29483935380975407
# Elapsed time: 38.136202335357666[s]
# Epoch 94/100
#  56/150 [==========>...................] - ETA: 22s - rpn_cls: 1.5277 - rpn_regr: 0.0648 - detector_cls: 1.2024 - detector_regr: 0.2879Average number of overlapping bounding boxes from RPN = 22.54 for 150 previous iterations
# 128/150 [========================>.....] - ETA: 5s - rpn_cls: 1.3485 - rpn_regr: 0.0767 - detector_cls: 1.1619 - detector_regr: 0.3038Exception: 'NoneType' object is not subscriptable
# 137/150 [==========================>...] - ETA: 3s - rpn_cls: 1.3324 - rpn_regr: 0.0774 - detector_cls: 1.1607 - detector_regr: 0.3050Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 1.3080 - rpn_regr: 0.0784 - detector_cls: 1.1596 - detector_regr: 0.3057
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.76158940397351
# Classifier accuracy for bounding boxes from RPN: 0.635
# Loss RPN classifier: 1.0823425819182824
# Loss RPN regression: 0.08784757333186766
# Loss Detector classifier: 1.1419842288891475
# Loss Detector regression: 0.30791542523850995
# Elapsed time: 37.36943531036377[s]
# Total loss decreased from 2.760454077656001 to 2.6200898093778076, saving weights
# Epoch 95/100
#  55/150 [==========>...................] - ETA: 24s - rpn_cls: 1.2352 - rpn_regr: 0.0980 - detector_cls: 0.8704 - detector_regr: 0.3153Average number of overlapping bounding boxes from RPN = 22.413333333333334 for 150 previous iterations
#  81/150 [===============>..............] - ETA: 17s - rpn_cls: 1.1827 - rpn_regr: 0.1017 - detector_cls: 0.9067 - detector_regr: 0.3165Exception: 'NoneType' object is not subscriptable
# 100/150 [===================>..........] - ETA: 12s - rpn_cls: 1.1708 - rpn_regr: 0.1027 - detector_cls: 0.9284 - detector_regr: 0.3167Exception: 'NoneType' object is not subscriptable
# 150/150 [==============================] - 38s 252ms/step - rpn_cls: 1.1851 - rpn_regr: 0.1028 - detector_cls: 0.9697 - detector_regr: 0.3157
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.483443708609272
# Classifier accuracy for bounding boxes from RPN: 0.6583333333333333
# Loss RPN classifier: 1.1241115363204985
# Loss RPN regression: 0.09855439625059564
# Loss Detector classifier: 1.0686170766005914
# Loss Detector regression: 0.30518982172012327
# Elapsed time: 40.450305461883545[s]
# Total loss decreased from 2.6200898093778076 to 2.596472830891809, saving weights
# Epoch 96/100
#  54/150 [=========>....................] - ETA: 24s - rpn_cls: 2.6314 - rpn_regr: 0.1177 - detector_cls: 1.1719 - detector_regr: 0.2925Average number of overlapping bounding boxes from RPN = 24.30666666666667 for 150 previous iterations
# 150/150 [==============================] - 38s 251ms/step - rpn_cls: 1.7752 - rpn_regr: 0.1127 - detector_cls: 1.1808 - detector_regr: 0.2886
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.794701986754966
# Classifier accuracy for bounding boxes from RPN: 0.6133333333333333
# Loss RPN classifier: 1.3677921648859093
# Loss RPN regression: 0.11424883130627374
# Loss Detector classifier: 1.1924321054418883
# Loss Detector regression: 0.2907874362543225
# Elapsed time: 40.393105268478394[s]
# Epoch 97/100
#  53/150 [=========>....................] - ETA: 24s - rpn_cls: 1.0011 - rpn_regr: 0.0870 - detector_cls: 1.1089 - detector_regr: 0.3107Average number of overlapping bounding boxes from RPN = 25.36 for 150 previous iterations
# 150/150 [==============================] - 37s 246ms/step - rpn_cls: 1.1513 - rpn_regr: 0.0954 - detector_cls: 1.0782 - detector_regr: 0.3145
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.397350993377483
# Classifier accuracy for bounding boxes from RPN: 0.6666666666666666
# Loss RPN classifier: 1.2988405265835434
# Loss RPN regression: 0.09820683508490523
# Loss Detector classifier: 1.0370162470142046
# Loss Detector regression: 0.3143436847627163
# Elapsed time: 37.219215869903564[s]
# Epoch 98/100
#   8/150 [>.............................] - ETA: 34s - rpn_cls: 2.3487 - rpn_regr: 0.0975 - detector_cls: 0.9256 - detector_regr: 0.3143Exception: 'NoneType' object is not subscriptable
#  52/150 [=========>....................] - ETA: 24s - rpn_cls: 2.5260 - rpn_regr: 0.0938 - detector_cls: 0.9957 - detector_regr: 0.2798Average number of overlapping bounding boxes from RPN = 21.56 for 150 previous iterations
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 2.0778 - rpn_regr: 0.0949 - detector_cls: 1.0379 - detector_regr: 0.2807
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.99337748344371
# Classifier accuracy for bounding boxes from RPN: 0.67
# Loss RPN classifier: 1.6440700357404232
# Loss RPN regression: 0.09376269340204696
# Loss Detector classifier: 1.0365961750845114
# Loss Detector regression: 0.27519601967185736
# Elapsed time: 37.51239895820618[s]
# Epoch 99/100
#  51/150 [=========>....................] - ETA: 24s - rpn_cls: 1.6025 - rpn_regr: 0.1005 - detector_cls: 1.1621 - detector_regr: 0.3446Average number of overlapping bounding boxes from RPN = 21.82 for 150 previous iterations
# 150/150 [==============================] - 37s 248ms/step - rpn_cls: 1.6572 - rpn_regr: 0.1008 - detector_cls: 1.1931 - detector_regr: 0.3203
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.980132450331126
# Classifier accuracy for bounding boxes from RPN: 0.66
# Loss RPN classifier: 1.7714786318959101
# Loss RPN regression: 0.10637543025116125
# Loss Detector classifier: 1.185916600500544
# Loss Detector regression: 0.3080074356744687
# Elapsed time: 37.45642113685608[s]
# Epoch 100/100
#   5/150 [>.............................] - ETA: 36s - rpn_cls: 1.4422 - rpn_regr: 0.0923 - detector_cls: 1.3966 - detector_regr: 0.3715Exception: 'NoneType' object is not subscriptable
#  50/150 [=========>....................] - ETA: 24s - rpn_cls: 1.1029 - rpn_regr: 0.1125 - detector_cls: 1.1628 - detector_regr: 0.3238Average number of overlapping bounding boxes from RPN = 21.606666666666666 for 150 previous iterations
# 150/150 [==============================] - 37s 244ms/step - rpn_cls: 1.5039 - rpn_regr: 0.1098 - detector_cls: 1.1594 - detector_regr: 0.3058
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.834437086092716
# Classifier accuracy for bounding boxes from RPN: 0.6333333333333333
# Loss RPN classifier: 1.605227080206585
# Loss RPN regression: 0.11261818646142881
# Loss Detector classifier: 1.1373525014022987
# Loss Detector regression: 0.3053681314736605
# Elapsed time: 36.8335063457489[s]
# training is done
# -------------------------------
# path to config file : ./save/train_20190611-053514_config.pickle
# -------------------------------

# %% [markdown]
# <img src="./result_sinpthons.png">

# %% [markdown]
# <img src="./result_yjimage.jpeg.png">
